# %%
import os
import csv
import re
from collections import defaultdict
import copy

# %%
f = open('litclock_annotated.csv')
reader = csv.DictReader(f, delimiter='|')
quotes = list(reader)

# %%
buckets = defaultdict(list)
for row in quotes:
    buckets[row['time']].append(row)
print(f"Number of time buckets: {len(buckets.keys())}")
print(f"Number of minutes in a day: {60 * 24}")
print(f"diff: {len(buckets.keys()) - (60*24)}")
# Out:
# Number of time buckets: 895
# Number of minutes in a day: 1440
# diff: -545

# %%
[bucket["quote"][:60] for bucket in buckets["00:05"]]
# Out:
# ['E.M. Security, normally so scrupulous with their fucking tru']

# %%
def does_quote_have_day_or_night_hints(quote):
    quote_string = quote["quote"].lower()
    time_string = quote["time_string"].lower()
    return any([
        re.search("(midnight|noon)", quote_string),
        re.search("(morn|nigh)", quote_string),
        re.search("(bed|sleep|wake|woke|rise|dawn|get up|dusk|sun)", quote_string),
        re.search("(am|pm|a.m.|p.m.)", quote_string),
        re.search("(0000|^0|^1[3-9]|^2[0-3])", time_string),
        re.search("(^.* 2[0-3])", time_string),

    ])

# %%
assert does_quote_have_day_or_night_hints({"quote":"The clock struck midnight", "time_string":"midnight"})
assert does_quote_have_day_or_night_hints({"quote":"It was morning, 06:00", "time_string": "06:00"})
assert does_quote_have_day_or_night_hints({"quote":"Let me go to bed, it is 8:45", "time_string":"8:45"})
assert does_quote_have_day_or_night_hints({"quote":"clock says 23:59", "time_string":"23:59"})
assert does_quote_have_day_or_night_hints({"quote":"well after 2245h", "time_string":"well after 2245h"})
assert not does_quote_have_day_or_night_hints({"quote":"only 12:45", "time_string":"12:45"})

# %%
def is_quote_duplicated_already(quote, buckets):
    time = quote["time"]
    newtime = get_other_time(time)
    newquote = copy.copy(quote)
    newquote["time"] = newtime
    return newquote in buckets.get(newtime, [])

def get_other_time(time):
    hour = int(time.split(":")[0])
    minute = int(time.split(":")[1])
    newhour = (hour + 12) % 24
    newtime = f"{newhour:02d}:{minute:02d}"
    return newtime

# %%
non_dupe_quote1 = {"time":"01:42", "quote":"non_dup_quote1"}
dupe_quote_1 = {"time":"03:00", "quote":"dup_quote1"}
dupe_quote_2 = {"time":"15:00", "quote":"dup_quote1"}
test_buckets = {
    "01:42": [non_dupe_quote1],
    "03:00": [dupe_quote_1],
    "15:00": [dupe_quote_2],
}
assert is_quote_duplicated_already(non_dupe_quote1, test_buckets) is False
assert is_quote_duplicated_already(dupe_quote_1, test_buckets) is True
assert is_quote_duplicated_already(dupe_quote_2, test_buckets) is True

assert get_other_time("00:01") == "12:01"
assert get_other_time("14:42") == "02:42"

# %%
newquotes = copy.copy(quotes)
for quote in quotes:
    if is_quote_duplicated_already(quote, buckets):
        continue
    elif does_quote_have_day_or_night_hints(quote):
        continue
    else:
        print(f"Duplicating: {quote}")
        newquote = copy.copy(quote)
        newquote["time"] = get_other_time(newquote["time"])
        newquotes.append(newquote)
        
len(newquotes)
# Out:
# Duplicating: OrderedDict([('time', '00:00'), ('time_string', 'twelve'), ('quote', "'Myself!' she gasped, 'and the clock is striking twelve! It's true, then! that's dreadful!'"), ('book', 'Wuthering Heights'), ('author', '')])
# Duplicating: OrderedDict([('time', '00:00'), ('time_string', 'twelve'), ('quote', 'The clock striketh twelve O it strikes, it strikes! Now body, turn to air, Or Lucifer will bear thee quick to hell.'), ('book', 'Dr Faustus'), ('author', '')])
# Duplicating: OrderedDict([('time', '00:15'), ('time_string', 'twelve-fifteen'), ('quote', 'At twelve-fifteen he got out of the van. He tucked the pistol under the waistband of his trousers and crossed the silent, deserted street to the Hudston house.'), ('book', 'Watchers'), ('author', 'Dean Koontz')])
# Duplicating: OrderedDict([('time', '00:17'), ('time_string', 'seventeen minutes after twelve'), ('quote', 'Kava ordered two glasses of coffee for himself and his beloved and some cake. When the pair left, exactly seventeen minutes after twelve, the club began to buzz with excitement.'), ('book', 'Vanvild Kava'), ('author', '')])
# Duplicating: OrderedDict([('time', '00:29'), ('time_string', 'Twenty-nine minutes past twelve'), ('quote', '...The station agent hauled out his big silver watch, looked at it critically and announced: Twenty-nine minutes past twelve." "Past twelve!" repeated Teeny-bits.'), ('book', 'The Mark of the Knife'), ('author', '')])
# Duplicating: OrderedDict([('time', '00:30'), ('time_string', 'half-past twelve'), ('quote', 'It was half-past twelve when I returned to the Albany as a last desperate resort. The scene of my disaster was much as I had left it.'), ('book', 'The Amateur Cracksman'), ('author', '')])
# Duplicating: OrderedDict([('time', '00:40'), ('time_string', 'twenty to one'), ('quote', "We sat in the car park till twenty to one. And now I'm engaged to Miss Joan Hunter Dunn."), ('book', "A Subaltern's Love Song"), ('author', '')])
# Duplicating: OrderedDict([('time', '00:45'), ('time_string', '12.45'), ('quote', 'At 12.45, during a lull, Mr Yoshogi told me that owing to the war there were now many more women in England than men.'), ('book', 'Pig and Pepper: A Comedy of Youth'), ('author', 'David Footman')])
# Duplicating: OrderedDict([('time', '00:54'), ('time_string', 'six minutes to one'), ('quote', '...songs, anecdotes, and more drinks followed, and the pregnant minutes flew. At six minutes to one, when the jollity was at its highest- BOOM! There was silence instantly.'), ('book', 'A Double Barrelled Detective Story'), ('author', 'Mark Twain')])
# Duplicating: OrderedDict([('time', '01:00'), ('time_string', "nearly one o'clock"), ('quote', "It was then nearly one o'clock. All I could discern distinctly by the moonlight was a colourless, youthful face."), ('book', 'The Woman in White'), ('author', 'Wilkie Collins')])
# Duplicating: OrderedDict([('time', '01:11'), ('time_string', 'nearer to one than half past'), ('quote', 'Declares one of the waiters was the worse for liquor, and that he was giving him a dressing down. Also that it was nearer to one than half past.'), ('book', 'The Affair at the Victory Ball'), ('author', 'Agatha Christie')])
# Duplicating: OrderedDict([('time', '01:16'), ('time_string', 'sixteen past one'), ('quote', 'At sixteen past one, they walked into the interview room.'), ('book', 'Nothing Gold Can Stay'), ('author', 'Dana Stabenow')])
# Duplicating: OrderedDict([('time', '01:17'), ('time_string', '1:17'), ('quote', 'The clocks stopped at 1:17. A long shear of light and then a series of low concussions. He got up and went to the window. What is it? she said. He didnt answer.'), ('book', 'The Road'), ('author', 'Cormac McCarthy')])
# Duplicating: OrderedDict([('time', '01:22'), ('time_string', '1:22'), ('quote', "It was 1:22 when we found Dad's grave."), ('book', 'Extremely Loud and Incredibly Close'), ('author', 'Jonathan Safran Foer')])
# Duplicating: OrderedDict([('time', '01:27'), ('time_string', 'twenty-seven minutes past one'), ('quote', 'At twenty-seven minutes past one she felt as if she was levitating out of her body.'), ('book', 'Trackers'), ('author', 'Deon Meyer')])
# Duplicating: OrderedDict([('time', '01:32'), ('time_string', 'One-thirty-two'), ('quote', 'She grinned at him with malicious playfulness, showing great square teeth, and then ran for the stairs. One-thirty-two. She thought that she heard a whistle blown...'), ('book', 'Stamboul Train'), ('author', 'Graham Greene')])
# Duplicating: OrderedDict([('time', '01:51'), ('time_string', 'nine minutes to two'), ('quote', "At nine minutes to two the other vehicle arrived. At first Milla didn't believe her eyes: that shape, those markings."), ('book', 'Trackers'), ('author', 'Deon Meyer')])
# Duplicating: OrderedDict([('time', '02:00'), ('time_string', 'It struck two.'), ('quote', 'After an unnaturally prolonged wheezing there followed a shrill, nasty, and as it were unexpectedly rapid, chime - as though someone were suddenly jumping forward. It struck two.'), ('book', 'Notes From the Underground'), ('author', 'Fyodor Dostoyevsky')])
# Duplicating: OrderedDict([('time', '02:05'), ('time_string', 'Five minutes past two'), ('quote', "What time is it?' 'Five minutes past two, sir,' answered the man, looking at the clock and yawning. 'Five minutes past two? How horribly late!"), ('book', 'The Picture of Dorian Gray'), ('author', 'Oscar Wilde')])
# Duplicating: OrderedDict([('time', '02:10'), ('time_string', 'Ten minutes past two'), ('quote', 'Ten minutes past two, sir, answered the man, looking at the clock and blinking. "Ten minutes past two? How horribly late!"'), ('book', 'The Picture of Dorian Gray'), ('author', 'Oscar Wilde')])
# Duplicating: OrderedDict([('time', '02:17'), ('time_string', '2.17'), ('quote', 'The flare spluttered and faded, and now the glare of the spotlight blinded me. I sat very still. It was 2.17.'), ('book', 'The Ipcress File'), ('author', 'Len Deighton')])
# Duplicating: OrderedDict([('time', '02:20'), ('time_string', 'Two-twenty'), ('quote', "She turned abruptly to the nurse and asked the time. 'Two-twenty' 'Ah...Two-twenty!' Genevieve repeated, as though there was something urgent to be done."), ('book', 'Southern Mail'), ('author', 'Antoine de Saint Exupery')])
# Duplicating: OrderedDict([('time', '02:46'), ('time_string', 'Two forty-six'), ('quote', "Vicki shoved her glasses at her face and peered at the clock. Two forty-six. 'I don't have time for this' she muttered..."), ('book', 'Blood Lines'), ('author', 'Tanya Huff')])
# Duplicating: OrderedDict([('time', '02:56'), ('time_string', '2:56'), ('quote', 'It was 2:56 when the shovel touched the coffin. We all heard the sound and looked at each other.'), ('book', 'Extremely Loud and Incredibly Close'), ('author', 'Jonathan Safran Foer')])
# Duplicating: OrderedDict([('time', '03:00'), ('time_string', '300'), ('quote', "The Regrouting Committee's been dragging along since may. Suddenly they're pulling secret 0300 milk-switches? It doesn't ring true, Jim."), ('book', 'Infinite Jest'), ('author', 'David Foster Wallace')])
# Duplicating: OrderedDict([('time', '03:00'), ('time_string', 'three'), ('quote', 'Why, if you listen you will hear it strike. George listened, and a neighbouring clock immediately obliged. "But it\'s only gone three!"'), ('book', 'Three Men in a Boat'), ('author', 'Jerome K Jerome')])
# Duplicating: OrderedDict([('time', '03:10'), ('time_string', 'ten past three'), ('quote', 'Love again; wanking at ten past three'), ('book', 'Love Again'), ('author', 'Philip Larkin')])
# Duplicating: OrderedDict([('time', '03:10'), ('time_string', 'ten-past three'), ('quote', "...the loss so you couldn't be charge for anything beyond the time of my calling them up. I looked at the clock. It was ten-past three."), ('book', 'The Whole Story and Other Stories'), ('author', 'Ali Smith')])
# Duplicating: OrderedDict([('time', '03:15'), ('time_string', '3:15'), ('quote', 'Above the door of Room 69 the clock ticked on at 3:15. The motion was accelerating. What had once been the gymnasium was now a small room...'), ('book', 'Manhole 69'), ('author', 'JG Ballard')])
# Duplicating: OrderedDict([('time', '03:21'), ('time_string', 'twenty-one minutes past three'), ('quote', 'Next, he remembered that the morrow of Christmas would be the twenty-seventh day of the moon, and that consequently high water would be at twenty-one minutes past three'), ('book', 'The Toilers of the Sea'), ('author', 'Victor Hugo')])
# Duplicating: OrderedDict([('time', '03:30'), ('time_string', 'Half past Three'), ('quote', 'At Half past Three, a single Bird Unto a silent Sky Propounded but a single term Of cautious melody.'), ('book', 'At Half past Three, a single Bird'), ('author', 'Emily Dickinson')])
# Duplicating: OrderedDict([('time', '03:42'), ('time_string', '3:42'), ('quote', 'We are due in Yellow Sky at 3:42, he said, looking tenderly into her eyes. "Oh, are we?" she said, as if she had not been aware of it.'), ('book', 'Bride Comes to Yellow Sky'), ('author', 'Stephen Crane')])
# Duplicating: OrderedDict([('time', '03:49'), ('time_string', '3.49'), ('quote', 'It was 3.49 when he hit me because of the two hundred times I had said, "I don\'t know." He hit me a lot after that.'), ('book', 'The Ipcress File'), ('author', 'Len Deighton')])
# Duplicating: OrderedDict([('time', '03:51'), ('time_string', '3:51'), ('quote', 'Sweat trickled down my ribs. The digital reading on the clock-radio was 3:51. Always odd numbered at times like this. What does it mean? Is death odd-numbered?'), ('book', 'White Noise'), ('author', 'Don DeLillo')])
# Duplicating: OrderedDict([('time', '03:51'), ('time_string', '3:51'), ('quote', 'The digital reading on the clock-radio was 3:51. Always odd numbers at times like this. What does it mean? Is death odd-numbered?'), ('book', 'White Noise'), ('author', 'Don DeLillo')])
# Duplicating: OrderedDict([('time', '03:58'), ('time_string', '3:58'), ('quote', 'The clock atop the clubhouse reads 3:58.'), ('book', 'Underworld'), ('author', 'Don Delillo')])
# Duplicating: OrderedDict([('time', '04:00'), ('time_string', 'at four'), ('quote', "Waking at four to soundless dark, I stare. In time the curtain-edges will grow light. Till then I see what's really always there: Unresting death"), ('book', 'Aubade'), ('author', 'Philip Larkin')])
# Duplicating: OrderedDict([('time', '04:04'), ('time_string', 'Four minutes after four!'), ('quote', "Four minutes after four! It's still very early and to get from here to there won't take me more than 15 minutes, even walking slowly."), ('book', 'Angel Hill'), ('author', 'Cirilo Villaverde')])
# Duplicating: OrderedDict([('time', '04:13'), ('time_string', '4:13'), ('quote', '...she opened her eyes to see digital numbers in the dark, 4:12 in pale green. Behind her Harry continued to move, settling in. She watched the numbers change to 4:13.'), ('book', 'Get Shorty'), ('author', 'Elmore Leonard')])
# Duplicating: OrderedDict([('time', '04:15'), ('time_string', 'four-fifteen'), ('quote', "...like flat feet or diabetes: they're all in danger of ending up alone by their own stubborn choice. The ugly kitchen clock says four-fifteen."), ('book', 'Pigs in Heaven'), ('author', 'Barbara Kingsolver')])
# Duplicating: OrderedDict([('time', '04:22'), ('time_string', '4.22'), ('quote', 'He hurt me to the point where I wanted to tell him something. My watch said 4.22 now. It had stopped. It was smashed.'), ('book', 'The Ipcress File'), ('author', 'Len Deighton')])
# Duplicating: OrderedDict([('time', '04:25'), ('time_string', 'twenty-five minutes past four'), ('quote', 'As I dressed I glanced at my watch. It was no wonder that no one was stirring. It was twenty-five minutes past four.'), ('book', 'The Adventures of Sherlock Holmes'), ('author', 'Sir Arthur Conan Doyle')])
# Duplicating: OrderedDict([('time', '04:30'), ('time_string', '430'), ('quote', 'Hester Thrale undulates in in a false fox jacket at 2330 as usual even though she has to be up at like 0430 for the breakfast shift at the Provident Nursing Home...'), ('book', 'Infinite Jest'), ('author', 'David Foster Wallace')])
# Duplicating: OrderedDict([('time', '04:41'), ('time_string', '4:41'), ('quote', 'At 4:41 Crane\'s voice crackled through the walkie-talkie as if he\'d read their thoughts of mutiny. "Everyone into the elevator. Now!"'), ('book', 'Damaged Goods: A Novel'), ('author', 'Roland S. Jefferson')])
# Duplicating: OrderedDict([('time', '04:54'), ('time_string', 'Six minutes to five'), ('quote', 'Six minutes to five. Six minutes to go. Suddenly I felt quite clearheaded. There was an unexpected light in the cell; the boundaries were drawn, the roles well defined.'), ('book', 'Dawn: A Novel'), ('author', 'Elie Wiesel')])
# Duplicating: OrderedDict([('time', '04:55'), ('time_string', '4:55'), ('quote', "4:55 - Mank holding phone. Turns to Caddell - 'Who is this?' Caddell: 'Jim.' (shrugs) 'I think he's our man in Cincinnati.'"), ('book', "Fear and Loathing: On the Campaign Trail '72"), ('author', 'Hunter S. Thompson')])
# Duplicating: OrderedDict([('time', '04:58'), ('time_string', 'Two minutes to five'), ('quote', 'He wants to look death in the face. Two minutes to five. I took a handkerchief out of my pocket, but John Dawson ordered me to put it back.'), ('book', 'Dawn: A Novel'), ('author', 'Elie Wiesel')])
# Duplicating: OrderedDict([('time', '04:59'), ('time_string', '4:59'), ('quote', 'The whole place smells like death no matter what the fuck you do. Gately gets to the shelter at 04:59 and just shuts his head off as if his head had a control switch.'), ('book', 'Infinite Jest'), ('author', 'David Foster Wallace')])
# Duplicating: OrderedDict([('time', '05:01'), ('time_string', 'one minute past five'), ('quote', 'Oh yes. His clocks were set at one minute past five, four minutes past five and seven minutes past five. That was the combination number of a safe, 515457.'), ('book', 'The Clocks'), ('author', 'Agatha Christie')])
# Duplicating: OrderedDict([('time', '05:04'), ('time_string', 'four minutes past five'), ('quote', 'Oh yes. His clocks were set at one minute past five, four minutes past five and seven minutes past five. That was the combination number of a safe, 515457.'), ('book', 'The clocks'), ('author', 'Agatha Christie')])
# Duplicating: OrderedDict([('time', '05:07'), ('time_string', 'seven minutes past five'), ('quote', 'Oh yes. His clocks were set at one minute past five, four minutes past five and seven minutes past five. That was the combination number of a safe, 515457.'), ('book', 'The clocks'), ('author', 'Agatha Christie')])
# Duplicating: OrderedDict([('time', '05:09'), ('time_string', '5:09'), ('quote', '...when inquiry of the station attendants educed the information that the two earliest trains to be obtained were the 5:09 to Dunkerque and the 5:37 for Ostend.'), ('book', 'The Black Bag'), ('author', 'Louis Joseph Vance')])
# Duplicating: OrderedDict([('time', '05:10'), ('time_string', 'Ten minutes past five'), ('quote', 'If this is not enough to kill me, I have more left in the bottle. Ten minutes past five. "You have just gone, after giving me my composing draught."'), ('book', 'The Law and the Lady'), ('author', 'Wilkie Collins')])
# Duplicating: OrderedDict([('time', '05:25'), ('time_string', '5.25'), ('quote', "George's train home from New Street leaves at 5.25. On the return journey, there are rarely schoolboys."), ('book', 'Arthur and George'), ('author', 'Julian Barnes')])
# Duplicating: OrderedDict([('time', '05:35'), ('time_string', '5:35'), ('quote', '5:35 - All phones ringing now, the swing shift has shot the gap - now the others are waking up.'), ('book', "Fear and Loathing: On the Campaign Trail '72"), ('author', 'Hunter S Thompson')])
# Duplicating: OrderedDict([('time', '05:35'), ('time_string', 'twenty-five before six'), ('quote', "I squinted at the clock. 'It says twenty-five before six,' I said and rolled away from him."), ('book', 'the dice man'), ('author', 'Luke Rhinehart')])
# Duplicating: OrderedDict([('time', '05:40'), ('time_string', 'Twenty minutes to six'), ('quote', "Twenty minutes to six. 'Rob's boys were already on the platform, barrows ready."), ('book', 'The Peculiar Memories of Thomas Penman'), ('author', 'Bruce Robinson')])
# Duplicating: OrderedDict([('time', '05:43'), ('time_string', '5.43'), ('quote', "5.43 - Mank on phone to 'Mary' in Washington; 'It now appears quite clear that we'll lead the state - without the 21st.'"), ('book', "Fear and Loathing: On the Campaign Trail '72"), ('author', 'Hunter S. Thompson')])
# Duplicating: OrderedDict([('time', '05:45'), ('time_string', '5:45'), ('quote', "At 5:45 a power-transformer on a pole beside the abandoned Tracker Brothers' Truck Depot exploded in a flash of purple light, spraying twisted chunks of metal..."), ('book', 'IT'), ('author', 'Stephen King')])
# Duplicating: OrderedDict([('time', '06:02'), ('time_string', '6.02'), ('quote', 'This train does not stop at Birchills, for reasons George has never been able to ascertain. Then it is Bloxwich 6.02, Wyrley & Churchbridge 6.09.'), ('book', 'Arthur and George'), ('author', 'Julian Barnes')])
# Duplicating: OrderedDict([('time', '06:05'), ('time_string', 'five minutes past six'), ('quote', 'A second man went in and found the shop empty, as he thought, at five minutes past six. That puts the time at between 5:30 and 6:05.'), ('book', 'The ABC Murders'), ('author', 'Agatha Christie')])
# Duplicating: OrderedDict([('time', '06:06'), ('time_string', '6:06'), ('quote', 'At 6:06, every toilet on Merit Street suddenly exploded in a geyser of shit and raw sewage as some unimaginable reversal took place...'), ('book', 'IT'), ('author', 'Stephen King')])
# Duplicating: OrderedDict([('time', '06:10'), ('time_string', 'ten past six'), ('quote', 'The bus left the station at ten past six - and she sat proud, like an accustomed traveller, apart from her father, John Henry, and Berenice.'), ('book', 'The Member of the Wedding'), ('author', 'Carson McCullers')])
# Duplicating: OrderedDict([('time', '06:15'), ('time_string', '6.15'), ('quote', 'Dumbbell exercise and wall-scaling ..... . 6.15-6.30'), ('book', 'The Great Gatsby'), ('author', 'F. Scott Fitzgerald')])
# Duplicating: OrderedDict([('time', '06:15'), ('time_string', 'quarter past six'), ('quote', "Father expected his shaving-water to be ready at a quarter past six. Just seven minutes late, Dorothy took the can upstairs and knocked at her father's door."), ('book', "A Clergyman's Daughter"), ('author', 'George Orwell')])
# Duplicating: OrderedDict([('time', '06:17'), ('time_string', 'six-seventeen'), ('quote', "Dizzy, come on.' He turned slowly, coaxing the animal down on to the pillow. The clock read six-seventeen. A second cat, Miles, purred on contentedly..."), ('book', 'Lonely Hearts'), ('author', 'John Harvey')])
# Duplicating: OrderedDict([('time', '06:30'), ('time_string', 'six-thirty'), ('quote', 'He was ready to close the door the second he was told to. "What time is it?" said his father in a drugged voice. "Oh my God, it\'s six-thirty," his mother said.'), ('book', 'The Book of Daniel'), ('author', 'E.L. Doctorow')])
# Duplicating: OrderedDict([('time', '06:30'), ('time_string', 'six-thirty'), ('quote', "Then he got back in the truck. The bar clock said six-thirty...By eight-thirty he'd decided that it that was it would take to make the cab arrive..."), ('book', 'Cities of the Plain'), ('author', 'Cormac McCarthy')])
# Duplicating: OrderedDict([('time', '06:35'), ('time_string', 'twenty-five minutes to seven'), ('quote', 'My watch lay on the dressing-table close by; glancing at it, I saw that the time was twenty-five minutes to seven.'), ('book', 'Ravensdene Court'), ('author', 'J.S. Fletcher')])
# Duplicating: OrderedDict([('time', '06:46'), ('time_string', 'one minute after the quarter to seven'), ('quote', 'At one minute after the quarter to seven I heard the rattle of the cans outside. I opened the front door, and there was my man...'), ('book', 'The Thirty-Nine Steps'), ('author', 'John Buchan')])
# Duplicating: OrderedDict([('time', '06:46'), ('time_string', 'one minute after the quarter to seven'), ('quote', '...but still he did not come. The fool had chosen this day of all days to be late. At one minute after the quarter to seven I heard the rattle of the cans outside.'), ('book', 'The Thirty-Nine Steps'), ('author', 'John Buchan')])
# Duplicating: OrderedDict([('time', '07:00'), ('time_string', 'at seven'), ('quote', 'I had left directions that I was to be called at seven; for it was plain that I must see Wemmick before seeing any one else'), ('book', 'Great Expectations'), ('author', 'Charles Dickens')])
# Duplicating: OrderedDict([('time', '07:00'), ('time_string', "seven o'clock"), ('quote', 'Seven o\'clock, already, he said to himself when the clock struck again, "seven o\'clock, and there\'s still a fog like this."'), ('book', 'Metamorphosis'), ('author', 'Franz Kafka')])
# Duplicating: OrderedDict([('time', '07:05'), ('time_string', 'five after seven'), ('quote', 'Outside my window the sky hung low and gray. It looked like snow, which added to my malaise. The clock read five after seven. I punched the remote control...'), ('book', 'Dance Dance Dance'), ('author', 'Haruki Murakami')])
# Duplicating: OrderedDict([('time', '07:05'), ('time_string', "five minutes after seven o'clock"), ('quote', "He decided he'd wait until five minutes after seven o'clock, and then he'd call in, take the day off, and make every effort in the book to locate someone reliable."), ('book', "Where I'm Calling From"), ('author', 'Raymond Carver')])
# Duplicating: OrderedDict([('time', '07:08'), ('time_string', "between eight and nine minutes after seven o'clock"), ('quote', "Reacher had no watch but he figured when he saw Gregory it must have been between eight and nine minutes after seven o'clock."), ('book', 'The Hard Way'), ('author', 'Lee Child')])
# Duplicating: OrderedDict([('time', '07:12'), ('time_string', '7:12'), ('quote', "...the 'stupid human habit' of arbitrarily choosing a time based on fifteen-minute intervals. 'Never meet people at 7:45 or 6:30, Jasper, but pick times like 7:12 and 8:03!'"), ('book', 'A Fraction of the Whole'), ('author', 'Steve Toltz')])
# Duplicating: OrderedDict([('time', '07:14'), ('time_string', '7.14'), ('quote', 'At 7.14 Harry knew he was alive. He knew that because the pain could be felt in every nerve fibre.'), ('book', 'The Redeemer'), ('author', 'Jo Nesbo')])
# Duplicating: OrderedDict([('time', '07:27'), ('time_string', '7.27'), ('quote', 'His appointment with the doctor was for 8.45. It was 7.27.'), ('book', 'The Return of the Dancing Master'), ('author', 'Henning Mankell')])
# Duplicating: OrderedDict([('time', '07:32'), ('time_string', '7:32'), ('quote', 'At 7:32, he suffered a fatal stroke.'), ('book', 'IT'), ('author', 'Stephen King')])
# Duplicating: OrderedDict([('time', '07:35'), ('time_string', 'Seven thirty-five'), ('quote', 'I looked at my watch. Seven thirty-five.'), ('book', 'Bare Bones'), ('author', 'Kathy Reichs')])
# Duplicating: OrderedDict([('time', '07:39'), ('time_string', '7.39'), ('quote', "Now, at the station, do you recall speaking to Mr Joseph Markew?' 'Yes, indeed. I was standing on the platform waiting for my usual train - the 7.39 - when he accosted me.'"), ('book', 'Arthur & George'), ('author', 'Julian Barnes')])
# Duplicating: OrderedDict([('time', '07:44'), ('time_string', 'seven forty-four'), ('quote', "It's not exactly how you'd choose to go, is it? You'd rather die flying a kite with your grandchildren, or at a great party or something. Not on the seven forty-four."), ('book', 'One Moment, One Morning'), ('author', 'Sarah Rayner')])
# Duplicating: OrderedDict([('time', '07:50'), ('time_string', 'ten minutes to eight'), ('quote', 'At about ten minutes to eight, Jim had squared the part of the work he had been doing - the window - so he decided not to start on the door or the skirting until after breakfast.'), ('book', 'The Ragged Trousered Philanthropists'), ('author', 'Robert Tressell')])
# Duplicating: OrderedDict([('time', '07:53'), ('time_string', 'Seven to eight'), ('quote', 'What time is it? "Seven to eight. Won\'t be long now ..."'), ('book', 'Never go back'), ('author', 'Robert Goddard')])
# Duplicating: OrderedDict([('time', '07:56'), ('time_string', 'four minutes to eight'), ('quote', 'The Castle Gate - only the Castle Gate - and it was four minutes to eight.'), ('book', 'Buddenbrooks'), ('author', 'Thomas Mann')])
# Duplicating: OrderedDict([('time', '08:00'), ('time_string', 'at eight'), ('quote', 'I hear noise at the ward door, off up the hall out of my sight. That ward door starts opening at eight and opens and closes a thousand times a day, kashash, click.'), ('book', "One Flew Over the Cuckoo's Nest"), ('author', 'Ken Kesey')])
# Duplicating: OrderedDict([('time', '08:00'), ('time_string', 'at eight'), ('quote', 'Too late. He must go on wanting what he had wanted yesterday. He dressed and rode down to the ground floor at eight for breakfast.'), ('book', 'Death in Venice'), ('author', 'Thomas Mann')])
# Duplicating: OrderedDict([('time', '08:00'), ('time_string', "eight o'clock"), ('quote', "But for now it was still eight o'clock, and as I walked along the avenue under that brilliant blue sky, I was happy, my friends, as happy as any man who had ever lived."), ('book', 'Brooklyn Follies'), ('author', 'Paul Auster')])
# Duplicating: OrderedDict([('time', '08:00'), ('time_string', "eight o'clock"), ('quote', "By eight o'clock Stillman would come out, always in his long brown overcoat, carrying a large, old-fashioned carpet bag. For two weeks this routine did not vary."), ('book', 'City of Glass'), ('author', 'Paul Auster')])
# Duplicating: OrderedDict([('time', '08:00'), ('time_string', 'exactly eight'), ('quote', 'The hands of the Dutch clock in the hall pointed to thirteen minutes past nine; those of the ormolu clock in the sitting-room to eleven minutes past ten'), ('book', 'Three Men and a Maid'), ('author', 'P.G. Wodehouse')])
# Duplicating: OrderedDict([('time', '08:01'), ('time_string', 'eight-one'), ('quote', "Eight-one, tick-tock, eight-one o'clock, off to school, off to work, run, run, eight-one!"), ('book', 'There Will Come Soft Rains'), ('author', 'Ray Bradbury')])
# Duplicating: OrderedDict([('time', '08:02'), ('time_string', 'Eight oh two'), ('quote', '... bingeley ... Eight oh two eh em, Death of Corporal Littlebottombottom ... Eight oh three eh em ... Death of Sergeant Detritus ...'), ('book', 'Jingo'), ('author', 'Terry Pratchett')])
# Duplicating: OrderedDict([('time', '08:03'), ('time_string', 'Eight oh three'), ('quote', '... bingeley ... Eight oh two eh em, Death of Corporal Littlebottombottom ... Eight oh three eh em ... Death of Sergeant Detritus ...'), ('book', 'Jingo'), ('author', 'Terry Pratchett')])
# Duplicating: OrderedDict([('time', '08:09'), ('time_string', '8:09'), ('quote', 'He followed the squeals down a hallway. A wall clock read 8:09 - 10:09 Dallas time.'), ('book', 'American Tabloid'), ('author', 'James Ellroy')])
# Duplicating: OrderedDict([('time', '08:10'), ('time_string', '8:10'), ('quote', 'Sloane, with his shoulder punctured, was on another lounge. He was half delirious, and kept calling something about a chemistry lecture at 8:10.'), ('book', 'This Side of Paradise'), ('author', 'F. Scott Fitzgerald')])
# Duplicating: OrderedDict([('time', '08:11'), ('time_string', 'eight-eleven'), ('quote', 'For some reason they both wore white rosettes pinned to their dresses. I looked again at the clock: eight-eleven.'), ('book', 'The Blackpool Highflyer'), ('author', 'Andrew Martin')])
# Duplicating: OrderedDict([('time', '08:15'), ('time_string', 'eight fifteen'), ('quote', 'You scrutinized your wrist: "It\'s eight fifteen. (And here time forked.) I\'ll turn it on." The screen In its blank broth evolved a lifelike blur, And music welled.'), ('book', 'Pale Fire'), ('author', '')])
# Duplicating: OrderedDict([('time', '08:16'), ('time_string', 'eight sixteen'), ('quote', 'I feel I should have something to read. Or someone to call. My fingers are itching to move. I look at my watch. Still only eight sixteen. Oh God.'), ('book', 'The Undomestic Goddess'), ('author', 'Sophie Kinsella')])
# Duplicating: OrderedDict([('time', '08:17'), ('time_string', 'eight seventeen'), ('quote', "I lean back and watch a little speckled bird pecking the ground nearby for a while. Then I look at my watch again: eight seventeen. I can't do this."), ('book', 'The Undomestic Goddess'), ('author', 'Sophie Kinsella')])
# Duplicating: OrderedDict([('time', '08:19'), ('time_string', '8.19'), ('quote', 'I had arranged to meet the Occupational Health Officer at 10:30. I took the train from Watford Junction at 8.19 and arrived at London Euston seven minutes late, at 8.49.'), ('book', 'The Terrible Privacy of Maxwell Sim'), ('author', 'Jonathan Coe')])
# Duplicating: OrderedDict([('time', '08:23'), ('time_string', '8:23'), ('quote', 'At 8:23 there seemed every chance of a lasting alliance starting between Florin and Guilder. At 8:24 the two nations were very close to war.'), ('book', 'The Princess Bride'), ('author', 'William Goldman')])
# Duplicating: OrderedDict([('time', '08:24'), ('time_string', '8:24'), ('quote', 'At 8:23 there seemed every chance of a lasting alliance starting between Florin and Guilder. At 8:24 the two nations were very close to war.'), ('book', 'The Princess Bride'), ('author', 'William Goldman')])
# Duplicating: OrderedDict([('time', '08:29'), ('time_string', '8.29'), ('quote', 'At 8.29 I punched the front doorbell in Elgin Crescent. It was opened by a small oriental woman in a white apron.'), ('book', 'Engleby'), ('author', 'Sebastian Faulks')])
# Duplicating: OrderedDict([('time', '08:30'), ('time_string', 'half past eight'), ('quote', 'At half past eight, Mr. Dursley picked up his briefcase, pecked Mrs. Dursley on the cheek, and tried to kiss Dudley good-bye but missed...'), ('book', "Harry Potter and the Philosopher's Stone"), ('author', 'JK Rowling')])
# Duplicating: OrderedDict([('time', '08:35'), ('time_string', 'thirty-five minutes past eight'), ('quote', 'It was thirty-five minutes past eight by the big clock of the central building when Mathieu crossed the yard towards the office which he occupied as chief designer.'), ('book', 'Fruitfulness'), ('author', 'Emile Zola')])
# Duplicating: OrderedDict([('time', '08:40'), ('time_string', '8.40'), ('quote', "At this moment the clock indicated 8.40. 'Five minutes more,' said Andrew Stuart. The five friends looked at each other."), ('book', 'Around the World in Eighty Days'), ('author', 'Jules Verne')])
# Duplicating: OrderedDict([('time', '08:40'), ('time_string', 'twenty minutes to nine'), ('quote', 'It was when I stood before her, avoiding her eyes, that I took note of the surrounding objects in detail, and saw that her watch had stopped at twenty minutes to nine...'), ('book', 'Great Expectations'), ('author', 'Charles Dickens')])
# Duplicating: OrderedDict([('time', '08:41'), ('time_string', 'forty-one minutes past eight'), ('quote', "By forty-one minutes past eight we are five hundred yards from the water's edge, and between our road and the foot of the mountain we descry..."), ('book', 'Narrative of a Journey round the Dead Sea and in the Bible lands in 1850 and 1851'), ('author', 'Felicien de Saulcy')])
# Duplicating: OrderedDict([('time', '08:47'), ('time_string', '8.47'), ('quote', '8.47. Bit misty on the roads'), ('book', "Dirk Gently's Holistic Detective Agency"), ('author', 'Douglas Adams')])
# Duplicating: OrderedDict([('time', '08:47'), ('time_string', '8.47'), ('quote', "Just on my way to the cottage. It's, er, ..8.47. Bit misty on the roads....."), ('book', "Dirk Gently's Holistic Detective Agency"), ('author', 'Douglas Adams')])
# Duplicating: OrderedDict([('time', '08:49'), ('time_string', '8.49'), ('quote', 'I had arranged to meet the Occupational Health Officer at 10:30. I took the train from Watford Junction at 8.19 and arrived at London Euston seven minutes late, at 8.49.'), ('book', 'The Terrible Privacy of Maxwell Sim'), ('author', 'Jonathan Coe')])
# Duplicating: OrderedDict([('time', '08:55'), ('time_string', 'five minutes to nine'), ('quote', 'George pulled out his watch and looked at it: it was five minutes to nine!'), ('book', 'Three Men in a Boat'), ('author', 'Jerome K Jerome')])
# Duplicating: OrderedDict([('time', '08:58'), ('time_string', 'two minutes of nine'), ('quote', 'It was two minutes of nine now - two minutes before the bombs were set to explode - and three or four people were gathered in front of the bank waiting for it to open.'), ('book', 'The Getaway'), ('author', 'Jim Thompson')])
# Duplicating: OrderedDict([('time', '09:00'), ('time_string', 'at nine'), ('quote', 'He was at breakfast at nine, and for the twentieth time consulted his "Bradshaw," to see at what earliest hour Dr. Grantly could arrive from Barchester.'), ('book', 'The Warden'), ('author', 'Anthony Trollope')])
# Duplicating: OrderedDict([('time', '09:00'), ('time_string', 'At nine'), ('quote', 'To be on the safe side, he did not unpack everything. At nine he went to breakfast in the specially designated buffet between the lobby and the dining room.'), ('book', 'Death in Venice'), ('author', 'Thomas Mann')])
# Duplicating: OrderedDict([('time', '09:00'), ('time_string', 'nine'), ('quote', 'A fly buzzed, the wall clock began to strike. After the nine golden strokes faded, the district captain began. "How is Herr Colonel Marek?" "Thank you, Papa, he\'s fine."'), ('book', 'The Radetzky March'), ('author', 'Joseph Roth')])
# Duplicating: OrderedDict([('time', '09:00'), ('time_string', "nine o' clock"), ('quote', "As nine o' clock was left behind, the preposterousness of the delay overwhelmed me, and I went in a kind of temper to the owner and said..."), ('book', 'A Single Pebble'), ('author', 'John Hershey')])
# Duplicating: OrderedDict([('time', '09:00'), ('time_string', "nine o'clock"), ('quote', "'I could never get all the way down there before nine o'clock.'"), ('book', 'A Confederacy of Dunces'), ('author', 'John Kennedy Toole')])
# Duplicating: OrderedDict([('time', '09:00'), ('time_string', "nine o'clock"), ('quote', "It was around nine o'clock that I crossed the border into Cornwall. This was at least three hours before the rain began and the clouds were still all of a brilliant white."), ('book', 'The Remains of the Day'), ('author', 'Kazuo Ishiguro')])
# Duplicating: OrderedDict([('time', '09:00'), ('time_string', 'nine'), ('quote', "The clock struck nine when I did send the nurse; In half an hour she promised to return. Perchance she cannot meet him: that's not so."), ('book', 'Romeo and Juliet'), ('author', 'Shakespeare')])
# Duplicating: OrderedDict([('time', '09:00'), ('time_string', 'nine'), ('quote', 'To where Saint Mary Woolnoth kept the hours With a dead sound on the final stroke of nine.'), ('book', 'The Waste Land'), ('author', 'T S Eliot')])
# Duplicating: OrderedDict([('time', '09:03'), ('time_string', 'three minutes past nine'), ('quote', '...bell had rung as I was crossing the playground, but you always get five minutes to get to your classroom. "It\'s three minutes past nine," Miss Beckworth announced.'), ('book', 'The Lottie Project'), ('author', 'Jacqueline Wilson')])
# Duplicating: OrderedDict([('time', '09:15'), ('time_string', '915'), ('quote', 'That\'s all right. Okay. Jones pulled a handful of pencils from his back pocket. "Now, I got the contact first at 0915 or so, and the bearing was about two-six-nine."'), ('book', 'The Hunt for Red October'), ('author', 'Tom Clancy')])
# Duplicating: OrderedDict([('time', '09:15'), ('time_string', 'quarter past nine'), ('quote', 'Miss Pettigrew pushed open the door of the employment agency and went in as the clock struck a quarter past nine.'), ('book', 'Miss Pettigrew Lives For a Day'), ('author', 'Winifred Watson')])
# Duplicating: OrderedDict([('time', '09:20'), ('time_string', 'nine-twenty'), ('quote', "I'll compromise by saying that I left home at eight and spent an hour travelling to a nine o'clock appointment. Twenty minutes later is nine-twenty."), ('book', 'Girl, Interrupted'), ('author', 'Susanna Kaysen')])
# Duplicating: OrderedDict([('time', '09:20'), ('time_string', 'twenty minutes past nine'), ('quote', 'At twenty minutes past nine, the Duke of Dunstable, who had dined off a tray in his room, was still there, waiting for his coffee and liqueur.'), ('book', 'Uncle Fred in the Springtime'), ('author', 'P.G. Wodehouse')])
# Duplicating: OrderedDict([('time', '09:21'), ('time_string', 'nine twenty-one'), ('quote', "It was nine twenty-one. With one minute to go, there was no sign of Herbert's mother."), ('book', 'This is Life'), ('author', 'Dan Rhodes')])
# Duplicating: OrderedDict([('time', '09:22'), ('time_string', 'nine twenty-two'), ('quote', "No more throwing stones at him, and I'll see you back here exactly one week from now. She looked at her watch. 'At nine twenty-two next Wednesday.'"), ('book', 'This is Life'), ('author', 'Dan Rhodes')])
# Duplicating: OrderedDict([('time', '09:23'), ('time_string', '9.23'), ('quote', '9.23. What possessed me to buy this comb?'), ('book', 'Ulysses'), ('author', 'James Joyce')])
# Duplicating: OrderedDict([('time', '09:24'), ('time_string', '9.24'), ('quote', "9.24 I'm swelled after that cabbage. A speck of dust on the patent leather of her boot."), ('book', 'Ulysses'), ('author', 'James Joyce')])
# Duplicating: OrderedDict([('time', '09:28'), ('time_string', 'twenty-eight minutes past nine'), ('quote', 'This clock right? he asked the butler in the hall. "Yes, sir." The clock showed twenty-eight minutes past nine. "The clocks here have to be right, sir."'), ('book', 'Lord Raingo'), ('author', 'Arnold Bennett')])
# Duplicating: OrderedDict([('time', '09:30'), ('time_string', 'half-past nine'), ('quote', 'he looked at his watch; it was half-past nine'), ('book', 'A watcher by the dead'), ('author', 'Ambrose Bierce')])
# Duplicating: OrderedDict([('time', '09:30'), ('time_string', 'nine-thirty'), ('quote', 'It was nine-thirty. In another ten minutes she would turn off the heat; then it would take a while for the water to cool. In the meantime there was nothing to do but wait.'), ('book', 'Revolutionary Road'), ('author', 'Richard Yates')])
# Duplicating: OrderedDict([('time', '09:32'), ('time_string', 'nine-thirty-two'), ('quote', "Sandy barely made the nine-thirty-two and found a seat in no-smoking. She'd been looking forward to this visit with Lisbeth."), ('book', 'Wifey'), ('author', 'Judy Blume')])
# Duplicating: OrderedDict([('time', '09:33'), ('time_string', 'thirty-three minutes past nine'), ('quote', '...the half-ebb at a quarter past seven, low water at thirty-three minutes past nine, and half flood at thirty-nine minutes past twelve.'), ('book', 'The Toilers of the Sea'), ('author', 'Victor Hugo')])
# Duplicating: OrderedDict([('time', '09:35'), ('time_string', 'Nine-thirty-five'), ('quote', 'Nine-thirty-five. He really must be gone. The bird is no longer feeding but sitting at the apex of a curl of razor wire.'), ('book', 'The Memory of Love'), ('author', 'Aminatta Forna')])
# Duplicating: OrderedDict([('time', '09:37'), ('time_string', 'thirty-seven minutes past nine'), ('quote', '...all the details of service, the tea and toast at twenty-three minutes past eight, the shaving-water at thirty-seven minutes past nine...'), ('book', 'Around the World in 80 days'), ('author', 'Jules Verne')])
# Duplicating: OrderedDict([('time', '09:40'), ('time_string', 'twenty minutes before ten'), ('quote', '... the tea and toast at twenty-three minutes past eight, the shaving-water at thirty-seven minutes past nine, and the toilet at twenty minutes before ten.'), ('book', 'Around the World in 80 days'), ('author', 'Jules Verne')])
# Duplicating: OrderedDict([('time', '09:45'), ('time_string', '9.45'), ('quote', "9.15, 9.30, 9.45, 10! Bond felt the excitement ball up inside him like cat's fur."), ('book', "On Her Majesty's Secret Service"), ('author', 'Ian Fleming')])
# Duplicating: OrderedDict([('time', '09:53'), ('time_string', 'seven minutes to ten'), ('quote', "The bus deposited her about five minutes' walk from Onslow Mansions, an at seven minutes to ten precisely she was outside her destination."), ('book', 'Miss Pettigrew Lives for a Day'), ('author', 'Winifred Watson')])
# Duplicating: OrderedDict([('time', '09:55'), ('time_string', 'five to ten'), ('quote', "At five to ten I'm ready in the hall. Nathaniel's mother's house is nearby but apparently tricky to find, so the plan is to meet here and he'll walk me over."), ('book', 'The Undomestic Goddess'), ('author', 'Sophie Kinsella')])
# Duplicating: OrderedDict([('time', '09:59'), ('time_string', 'One minute to ten.'), ('quote', 'One minute to ten. With a heavy heart Bert watched the clock. His legs were still aching very badly. He could not see the hands of the clock moving...'), ('book', 'The Ragged Trouserred Philanthropists'), ('author', 'Robert Tressell')])
# Duplicating: OrderedDict([('time', '10:00'), ('time_string', "10 o'clock"), ('quote', "Monday 30 March 1668 Up betimes, and so to the office, there to do business till about 10 o'clock"), ('book', 'The Diary of Samuel Pepys'), ('author', 'Samuel Pepys')])
# Duplicating: OrderedDict([('time', '10:00'), ('time_string', 'an hour ago since it was nine'), ('quote', "'Tis but an hour ago since it was nine, And after one hour more 'twill be eleven."), ('book', 'As You Like It'), ('author', 'William Shakespeare')])
# Duplicating: OrderedDict([('time', '10:02'), ('time_string', 'two minutes after ten'), ('quote', 'It was two minutes after ten; she was not satisfied with her clothes, her face, her apartment. She heated the coffee again and sat down in the chair by the window.'), ('book', 'The Daemon Lover'), ('author', 'Shirley Jackson')])
# Duplicating: OrderedDict([('time', '10:03'), ('time_string', '10.03'), ('quote', "...the time was twenty three minutes past ten, so he tapped in the numbers 10.23. At least, that's what he meant to do. In fact he typed in the numbers 10.03."), ('book', 'Ctrl-Z'), ('author', 'Andrew Norriss')])
# Duplicating: OrderedDict([('time', '10:05'), ('time_string', 'five past ten'), ('quote', 'Then I glance at my watch. It\'s already five past ten. "We should get going," I say with a little start. "Your mother will be waiting."'), ('book', 'The Undomestic Goddess'), ('author', 'Sophie Kinsella')])
# Duplicating: OrderedDict([('time', '10:09'), ('time_string', '10:09'), ('quote', 'He followed the squeals down a hallway. A wall clock read 8:09-10:09 Dallas time.'), ('book', 'American Tabloid'), ('author', 'James Ellroy')])
# Duplicating: OrderedDict([('time', '10:10'), ('time_string', '10:10'), ('quote', '10:10 Shot is fired.'), ('book', 'The Hollow Man'), ('author', 'John Dickson Carr')])
# Duplicating: OrderedDict([('time', '10:11'), ('time_string', 'eleven minutes past ten'), ('quote', '...those of the ormolu clock in the sitting-room to eleven minutes past ten; those of the carriage clock on the bookshelf to fourteen minutes to six.'), ('book', 'Three Men and a Maid'), ('author', 'P.G. Wodehouse')])
# Duplicating: OrderedDict([('time', '10:12'), ('time_string', 'Ten twelve'), ('quote', "I'll take the coffee tray out, I suggest humbly. As I pick it up I glance again at my watch. Ten twelve. I wonder if they've started the meeting."), ('book', 'The Undomestic Goddess'), ('author', 'Sophie Kinsella')])
# Duplicating: OrderedDict([('time', '10:13'), ('time_string', 'thirteen minutes past ten'), ('quote', 'And I sent it to the Daily Telegraph at thirteen minutes past ten. "Bravo, Mr. Blount!" "Very good, M. Jolivet."'), ('book', 'Michel Strogoff'), ('author', 'Jules Verne')])
# Duplicating: OrderedDict([('time', '10:14'), ('time_string', 'Ten fourteen'), ('quote', "Okay. Ten fourteen: Mrs. Narada reports that her cat has been attacked by a large dog. Now I send all the boys out looking, but they don't find anything until eleven."), ('book', 'Coyote Blue'), ('author', 'Christopher Moore')])
# Duplicating: OrderedDict([('time', '10:18'), ('time_string', '10:18'), ('quote', 'I know that it was 10:18 when I got home because I look at my watch a lot.'), ('book', 'Extremely Loud and Incredibly Close'), ('author', 'Jonathan Safran Foer')])
# Duplicating: OrderedDict([('time', '10:20'), ('time_string', 'twenty past ten'), ('quote', 'An hour and twenty-five minutes, she said. The right time now is twenty past ten.'), ('book', 'A Portrait of the Artist as a Young Man'), ('author', 'James Joyce')])
# Duplicating: OrderedDict([('time', '10:21'), ('time_string', '10.21'), ('quote', 'Liz Headleand stares into the mirror, as though entranced. She does not see herself or the objects on her dressing-table. The clock abruptly jerks to 10.21.'), ('book', 'The Radiant Way'), ('author', 'Margaret Drabble')])
# Duplicating: OrderedDict([('time', '10:22'), ('time_string', '10:22:27'), ('quote', '...then before I had time to figure out what to do, or even what to think or feel, the phone started ringing. It was 10:22:27. I looked at the caller ID and saw that it was him.'), ('book', 'Extremely Loud and Incredibly Close'), ('author', 'Jonathan Safran Foer')])
# Duplicating: OrderedDict([('time', '10:23'), ('time_string', 'twenty three minutes past ten'), ('quote', 'The date was the 14th of May and the clock on his desk said the time was twenty three minutes past ten, so he tapped in the numbers 10.23.'), ('book', 'Ctrl-Z'), ('author', 'Andrew Norriss')])
# Duplicating: OrderedDict([('time', '10:25'), ('time_string', '10:25'), ('quote', '10:25: Phone call from Luding, very worked up, urging me to return at once and get in touch with Alois, who was equally worked up.'), ('book', 'The Lost Honour of Katharina Blum'), ('author', 'Heinrich Boll')])
# Duplicating: OrderedDict([('time', '10:26'), ('time_string', '10:26'), ('quote', "10:26 No. Please, no. I can hardly bear to look. It's a total disaster. Everything in the washing machine has gone pink. Every single thing. What happened?"), ('book', 'The Undomestic Goddess'), ('author', 'Sophie Kinsella')])
# Duplicating: OrderedDict([('time', '10:30'), ('time_string', 'ten thirty'), ('quote', 'according to the clock on the wall, it is barely ten thirty.'), ('book', 'The Hours'), ('author', 'Michael Cunningham')])
# Duplicating: OrderedDict([('time', '10:36'), ('time_string', 'ten thirty-six'), ('quote', 'Strand post mark and dispatched ten thirty-six said Holmes reading it over and over.'), ('book', 'The Adventure of the Missing Three-Quarter'), ('author', 'Arthur Conan Doyle')])
# Duplicating: OrderedDict([('time', '10:38'), ('time_string', '10:38'), ('quote', 'Frantically I scan the cans of products stacked on the shelves. Stain Away. Vanish. There has to be a remedy. ... I just need to think. ... 10:38 OK, I have the answer.'), ('book', 'The Undomestic Goddess'), ('author', 'Sophie Kinsella')])
# Duplicating: OrderedDict([('time', '10:40'), ('time_string', '10:40'), ('quote', '10:40: Call from Katharina asking me whether I had really said what was in the News.'), ('book', 'The Lost Honour of Katharina Blum'), ('author', 'Heinrich Boll')])
# Duplicating: OrderedDict([('time', '10:45'), ('time_string', 'quarter to eleven'), ('quote', 'If this is so, we have now to determine what Barker and Mrs. Douglas, presuming they are not the actual murderers, would have been doing from quarter to eleven, when...'), ('book', 'The Valley of Fear'), ('author', 'Arthur Conan Doyle')])
# Duplicating: OrderedDict([('time', '10:45'), ('time_string', 'quarter to eleven'), ('quote', "They reached King's Cross at a quarter to eleven. Mr Weasley dashed across the road to get trolleys for their trunks and they all hurried into the station."), ('book', 'Harry Potter and the Chamber of Secrets'), ('author', 'J.K.Rowling')])
# Duplicating: OrderedDict([('time', '10:47'), ('time_string', '10.47'), ('quote', 'He whistles in the shower. It is 10.47 and he is ready for the off.'), ('book', 'Trumpet'), ('author', 'Jackie Kay')])
# ...
# Duplicating: OrderedDict([('time', '20:49'), ('time_string', '8.49'), ('quote', '8.49. I took the phone, cleared my throat, and dialled the keep, the packs stronghold on the outskirts of Atlanta. Just keep it professional. Less pathetic that way.'), ('book', 'Magic Bleeds'), ('author', 'Ilona Andrews')])
# Duplicating: OrderedDict([('time', '20:50'), ('time_string', 'ten minutes before nine'), ('quote', 'all the clocks in London were striking ten minutes before nine.'), ('book', 'Around the world in eighty days'), ('author', 'Jules Verne')])
# Duplicating: OrderedDict([('time', '20:50'), ('time_string', 'ten minutes to nine'), ('quote', 'He glanced at the bracket-clock on the mantelpiece, but as this had stopped, drew out his watch. "It is already too late," he said. "It wants only ten minutes to nine."'), ('book', 'The Reluctant Widow'), ('author', 'Georgette Heyer')])
# Duplicating: OrderedDict([('time', '20:50'), ('time_string', 'ten minutes to nine'), ('quote', 'What did it mean by beginning to tick so loudly all of a sudden? Its face indicated ten minutes to nine. Mrs Verloc cared nothing for time, and the ticking went on.'), ('book', 'The Secret Agent'), ('author', 'Joseph Conrad')])
# Duplicating: OrderedDict([('time', '20:53'), ('time_string', 'eight fifty-three'), ('quote', "Only eight fifty-three. The partners' decision meeting starts in seven minutes. I'm not sure I can bear this."), ('book', 'The Undomestic Goddess'), ('author', 'Sophie Kinsella')])
# Duplicating: OrderedDict([('time', '20:56'), ('time_string', 'four minutes to nine'), ('quote', 'No. 7 berth-a second-class. The gentleman has not yet come, and it is four minutes to nine.'), ('book', 'Murder on the Orient Express'), ('author', 'Agatha Christie')])
# Duplicating: OrderedDict([('time', '20:57'), ('time_string', 'three minutes to nine'), ('quote', "they're a nuisance, anyway--always ticking and striking and getting you late for dinner. He glanced again at the clock in the tower. The hands stood at three minutes to nine."), ('book', 'The Four Million'), ('author', 'O. Henry')])
# Duplicating: OrderedDict([('time', '20:58'), ('time_string', 'Two minutes to nine'), ('quote', 'What time is it? she asked, quiet, definite, hopeless. "Two minutes to nine," he replied, telling the truth with a struggle.'), ('book', 'Sons and Lovers'), ('author', 'D H Lawrence')])
# Duplicating: OrderedDict([('time', '21:00'), ('time_string', "nine o'clock"), ('quote', "On the stroke of nine o'clock Mr. and Mrs. De Voted took their places on either side of the drawing-room fire, in attitudes of gracefully combined hospitality and unconcern..."), ('book', 'A Marriage of Passion'), ('author', 'Katherine Mansfield')])
# Duplicating: OrderedDict([('time', '21:00'), ('time_string', "nine o'clock"), ('quote', "Shortly after nine o'clock that evening, Weyrother drove with his plans to Kutuzov's quarters where the council of war was to be held."), ('book', 'War and Peace'), ('author', 'Leo Tolstoy')])
# Duplicating: OrderedDict([('time', '21:03'), ('time_string', "about nine o'clock"), ('quote', "...with a change at Swindon on the way, and by the time he got to Bath it was about nine o'clock in the evening and the moon was coming up..."), ('book', 'The Landlady'), ('author', 'Roald Dahl')])
# Duplicating: OrderedDict([('time', '21:05'), ('time_string', 'nine-five'), ('quote', 'Nine-five. A voice spoke from the study ceiling: "Mrs. McClellan, which poem would you like this evening?". The house was silent.'), ('book', 'There will come soft rains'), ('author', 'Ray Bradbury')])
# Duplicating: OrderedDict([('time', '21:09'), ('time_string', '9.09'), ('quote', '9.09. Too late to turn around and go back. Too late, too dangerous.'), ('book', 'Dreams of Leaving'), ('author', 'Rupert Thomson')])
# Duplicating: OrderedDict([('time', '21:15'), ('time_string', '9.15'), ('quote', '9.15. Did Roberts pay you yet?'), ('book', 'Ulysses'), ('author', 'James Joyce')])
# Duplicating: OrderedDict([('time', '21:28'), ('time_string', '9:28'), ('quote', 'From that moment on--9:28 in the evening, June 18, 1941--everything was different.'), ('book', 'Everything is Illuminated'), ('author', 'Jonathan Safran Foer')])
# Duplicating: OrderedDict([('time', '21:31'), ('time_string', '9:31'), ('quote', 'On the table was a note from my girlfriend: "Gone out to eat. Back by 9:30." The digital clock on the table read 9:30. I watched it flip over to 9:31, then to 9:32.'), ('book', 'A Wild Sheep Chase'), ('author', 'Haruki Murakami')])
# Duplicating: OrderedDict([('time', '21:32'), ('time_string', '9:32'), ('quote', 'On the table was a note from my girlfriend: "Gone out to eat. Back by 9:30." The digital clock on the table read 9:30. I watched it flip over to 9:31, then to 9:32.'), ('book', 'A Wild Sheep Chase'), ('author', 'Haruki Murakami')])
# Duplicating: OrderedDict([('time', '21:47'), ('time_string', 'thirteen minutes to ten'), ('quote', 'For Hunter, who was trained to note times exactly, the final emergency started at thirteen minutes to ten.'), ('book', 'Elegy for a Revolutionary'), ('author', 'CJ Driver')])
# Duplicating: OrderedDict([('time', '22:00'), ('time_string', 'ten'), ('quote', 'By ten, Quoyle was drunk. The crowd was enormous, crushed together so densely that Nutbeem could not force his way down the hall...'), ('book', 'The Shipping News'), ('author', 'E. Annie Proulx')])
# Duplicating: OrderedDict([('time', '22:00'), ('time_string', "ten o'clock"), ('quote', 'Her body asserted itself with a restless movement of the knee, and she stood up. "Ten o\'clock," she remarked, apparently finding the time on the ceiling.'), ('book', 'The Great Gatsby'), ('author', 'F. Scott Fitzgerald')])
# Duplicating: OrderedDict([('time', '22:00'), ('time_string', "ten o'clock"), ('quote', "Florence set down her knife and reached for Edward's hand and squeezed. From downstairs they heard the wireless, the chimes of Big Ben at the start of the ten o'clock news."), ('book', 'On Chesil Beach'), ('author', 'Ian McEwan')])
# Duplicating: OrderedDict([('time', '22:00'), ('time_string', "ten o'clock"), ('quote', "...who appeared to have nothing to do on this particular evening; we simply could not get rid of him without being rude; he hung about until ten o'clock."), ('book', 'Anne Frank: The Diary of a Young Girl'), ('author', 'Anne Frank')])
# Duplicating: OrderedDict([('time', '22:00'), ('time_string', 'ten'), ('quote', 'The grandfather clock in the State Room strikes ten times.'), ('book', 'The Thousand Autumns of Jacob de Zoet'), ('author', 'David Mitchell')])
# Duplicating: OrderedDict([('time', '22:08'), ('time_string', 'ten eight'), ('quote', 'My watch is always a little fast, I said. "What time do you make it now?" "Ten eight." "Ten eighteen by mine. You see."'), ('book', 'The Quiet American'), ('author', 'Graham Greene')])
# Duplicating: OrderedDict([('time', '22:11'), ('time_string', 'eleven minutes past ten'), ('quote', 'Therefore a sergeant called Trifonov had been on post all day or all week and then he had left at eleven minutes past ten in the evening.'), ('book', 'The Enemy'), ('author', 'Lee Child')])
# Duplicating: OrderedDict([('time', '22:17'), ('time_string', '10:17 p. m.'), ('quote', '10:17 p. m. Casette will not go in'), ('book', "Bridget Jones's Diary"), ('author', 'Helen Fielding')])
# Duplicating: OrderedDict([('time', '22:18'), ('time_string', 'ten eighteen'), ('quote', 'My watch is always a little fast, I said. "What time do you make it now?" "Ten eight." "Ten eighteen by mine. You see."'), ('book', 'The Quiet American'), ('author', 'Graham Greene')])
# Duplicating: OrderedDict([('time', '22:20'), ('time_string', '10:20'), ('quote', 'At 10:20 she returned with a shopping bag from the supermarket. In the bag were three scrub brushes, one box of paperclips and a well-chilled six-pack of canned beer.'), ('book', 'A Wild Sheep Chase'), ('author', 'Haruki Murakami')])
# Duplicating: OrderedDict([('time', '22:30'), ('time_string', 'ten thirty'), ('quote', 'She looked at the clock; it was ten thirty. If she could get there quickly on the subway, then she could be at his house in less than an hour, maybe a bit longer...'), ('book', 'Brooklyn'), ('author', 'Colm Toibin')])
# Duplicating: OrderedDict([('time', '22:40'), ('time_string', 'twenty to eleven'), ('quote', "The station clock told him the time: twenty to eleven. He went to the booking office and asked the clerk in a polite tone when was the next train to Paris. 'In twelve minutes.'"), ('book', 'The Man Who Watched the Trains Go By'), ('author', 'Georges Simenon')])
# Duplicating: OrderedDict([('time', '22:41'), ('time_string', '10:41'), ('quote', 'There, the bastards, said Julian, and smashed the clock with the bottom of the bottle, to give them an approximate time. It was 10:41"'), ('book', 'Appointment in Samarra'), ('author', "John O'Hara")])
# Duplicating: OrderedDict([('time', '22:44'), ('time_string', 'About a quarter to eleven.'), ('quote', 'Alec pricked up his ears. "When was that?" "Oh, yesterday evening." "What time?" "About a quarter to eleven. I was playing bridge."'), ('book', 'Dead in the Water'), ('author', 'Carola Dunn')])
# Duplicating: OrderedDict([('time', '22:48'), ('time_string', '10.48'), ('quote', 'I was down there for a bit last summer. I found it quite convenient for town. Of course the trains only go every hour. 48 minutes past the hour from Waterloo-up to 10.48.'), ('book', 'The Sign in the Sky'), ('author', 'Agatha Christie')])
# Duplicating: OrderedDict([('time', '22:50'), ('time_string', 'ten to eleven'), ('quote', 'It\'s a hundred this year, ain\'t anybody noticed? Jack said, "What\'s a hundred?" I said, "Pub is. Coach is. Look at the clock." Jack said, "It\'s ten to eleven"'), ('book', 'Last Orders'), ('author', 'Graham Swift')])
# Duplicating: OrderedDict([('time', '22:55'), ('time_string', "Eleven o'clock, all but five minutes!"), ('quote', 'It is eleven o\'clock! Eleven o\'clock, all but five minutes! "But which eleven o\'clock?" "The eleven o\'clock that is to decide life or death!"'), ('book', 'The Phantom of the Opera'), ('author', 'Gaston Leroux')])
# Duplicating: OrderedDict([('time', '22:59'), ('time_string', 'one minute to eleven'), ('quote', "They parked the car outside Lowther's at precisely one minute to eleven. People were leaving, not all of them happy at having their evening curtailed."), ('book', 'The Complaints'), ('author', 'Ian Rankin')])
# Duplicating: OrderedDict([('time', '23:00'), ('time_string', 'At eleven'), ('quote', "'He will be here at eleven exactly, sir.' At the bar, naked couples had begun dancing."), ('book', "Smiley's People"), ('author', 'John le Carre')])
# Duplicating: OrderedDict([('time', '23:00'), ('time_string', "eleven o'clock"), ('quote', 'He says, "They\'ve killed Jan. Clear out." "The suitcase?" I ask. "Take it away again. We want nothing to do with it now. Catch the eleven o\'clock express."'), ('book', "If on a winter's night a traveller"), ('author', 'Italo Calvino')])
# Duplicating: OrderedDict([('time', '23:03'), ('time_string', 'Eleven oh-three'), ('quote', 'Good question. Guess I\'ll find out. She went back into the kitchen. "What time are you meeting him?" she called out. "Eleven oh-three," he said.'), ('book', 'Little Green Men'), ('author', 'Christopher Buckley')])
# Duplicating: OrderedDict([('time', '23:10'), ('time_string', 'ten minutes past eleven'), ('quote', 'He had not the strength to help himself, and at ten minutes past eleven no one could have helped him, no one in the world'), ('book', 'Appointment in Samarra'), ('author', "John O'Hara")])
# Duplicating: OrderedDict([('time', '23:15'), ('time_string', 'quarter-past eleven'), ('quote', 'On arriving home at a quarter-past eleven, we found a hansom cab, which had been waiting for me for two hours with a letter.'), ('book', 'Dairy of a Nobody'), ('author', 'George and Weedon Grossmith')])
# Duplicating: OrderedDict([('time', '23:20'), ('time_string', 'eleven-twenty'), ('quote', 'From Balboa Island, he drove south to Laguna Beach. At eleven-twenty, he parked his van across the street from the Hudston house.'), ('book', 'Watchers'), ('author', 'Dean Koontz')])
# Duplicating: OrderedDict([('time', '23:22'), ('time_string', '11.22'), ('quote', 'At 11.22 he handed his ticket to a yawning guard and walked down a long flight of wooden steps to the car-park. A breeze lifted and dropped the leaves of a tree...'), ('book', 'Dreams of leaving'), ('author', 'Robert Thomson')])
# Duplicating: OrderedDict([('time', '23:25'), ('time_string', "eleven o'clock and twenty-five minutes"), ('quote', "...see if he could make out the figures on the dial. They were plainly visible, and the hands indicated the hour of eleven o'clock and twenty-five minutes."), ('book', 'A Wireless Message'), ('author', 'Ambrose Bierce')])
# Duplicating: OrderedDict([('time', '23:30'), ('time_string', 'half past eleven'), ('quote', "The ship's clock in the bar says half past eleven. Half past eleven is opening time. The hands of the clock have stayed still at half past eleven for fifty years."), ('book', 'Under Milk Wood'), ('author', 'Dylan Thomas')])
# Duplicating: OrderedDict([('time', '23:34'), ('time_string', 'Eleven thirty-four'), ('quote', "Eleven thirty-four. We stand on the sidewalk in front of Jean's apartment on the Upper East Side."), ('book', 'American Psycho'), ('author', 'Bret Easton Ellis')])
# Duplicating: OrderedDict([('time', '23:34'), ('time_string', 'eleven thirty-four'), ('quote', 'Reacher retrieved his G36 from under the saloon bar window at eleven thirty-four precisely and set out to walk back on the road...'), ('book', 'The Hard Way'), ('author', 'Lee Child')])
# Duplicating: OrderedDict([('time', '23:35'), ('time_string', 'eleven thirty-five'), ('quote', 'Then at eleven thirty-five the door at the rear of the hall opened and a police sergeant and three constables entered, ushered by Bagot.'), ('book', 'Hamlet, Revenge!'), ('author', 'Michael Innes')])
# Duplicating: OrderedDict([('time', '23:41'), ('time_string', '11:41'), ('quote', 'The phosphorescent figures on his watch attracted his attention. He peered at them. The time was 11:41. I remember...what do I remember?'), ('book', 'Noble House'), ('author', 'James Clavell')])
# Duplicating: OrderedDict([('time', '23:43'), ('time_string', 'eleven forty-three'), ('quote', "The clock told him it was eleven forty-three and in that moment, in a flash of illumination, Mungo understood what the numbers at the end of Moscow Centre's messages were"), ('book', 'Talking to Strange Men'), ('author', 'Ruth Rendell')])
# Duplicating: OrderedDict([('time', '23:45'), ('time_string', 'quarter to twelve'), ('quote', "We passed Shiplake as the clock was striking the quarter to twelve and then George said thoughtfully: 'You don't happen to remember which of the islands it was, do you?'"), ('book', 'Three Men in a Boat'), ('author', 'Jerome K. Jerome')])
# Duplicating: OrderedDict([('time', '23:45'), ('time_string', 'three quarters past eleven'), ('quote', 'The church clocks chimed three quarters past eleven, as two figures emerged on London Bridge.'), ('book', 'Oliver Twist'), ('author', 'Charles Dickens')])
# Duplicating: OrderedDict([('time', '23:51'), ('time_string', 'eleven-fifty-one'), ('quote', 'Due at Waterloo at eleven-fifty-one, panted Smith. "That gives us thirty-nine minutes to get to the other side of the river and reach his hotel."'), ('book', 'The Mystery of Dr Fu Manchu'), ('author', 'Sax Rohmer')])
# Duplicating: OrderedDict([('time', '23:57'), ('time_string', 'eleven fifty-seven'), ('quote', 'Wells looked out at the street. "What time is it?" he said. Chigurh raised his wrist and looked at his watch. "Eleven fifty-seven" he said. Wells nodded.'), ('book', 'No Country for Old Men'), ('author', 'Cormac McCarthy')])
# 1885

# %%
newbuckets = {q["time"] for q in newquotes}
print(f"new diff: {len(newbuckets) - (60*24)}")
# Out:
# new diff: -441

# %%
with open('litclock_expanded_meridiem.csv', "w") as newcsv:
    newcsv_writer = csv.DictWriter(newcsv, delimiter="|", fieldnames=reader.fieldnames)
    newcsv_writer.writeheader()
    for q in newquotes:
        newcsv_writer.writerow(q)
os.system("sort litclock_expanded_meridiem.csv > 1.csv && mv 1.csv litclock_expanded_meridiem.csv")
# Out:
# 0

# %% [markdown]
# ## Analysis
#
# What is the biggest gap in time? With 1440 unique minutes, and 999 available minutes to fill those slots, there is going to be period of time where there are gaps. What is the biggest gap? How "off" could this watch be at any given time?

# %%
def human_time_to_minute_number(time):
    hour = int(time.split(":")[0])
    minute = int(time.split(":")[1])
    return hour * 60 + minute
assert human_time_to_minute_number("00:01") == 1
assert human_time_to_minute_number("12:42") == 762

newbuckets = {q["time"] for q in newquotes}
newminutes = sorted([human_time_to_minute_number(t) for t in newbuckets])

# %%
def get_longest_gap(numbers):
    prev = numbers[0]
    max_gap = 0
    longest_gap_index = 0
    for index, n in enumerate(numbers):
        gap = n - numbers[index-1]
        if gap > max_gap:
            max_gap = gap
            longest_gap_index = index
    print(f"The longest gap is between {numbers[longest_gap_index-1]} and {numbers[longest_gap_index]}")
    print(f"With a gap of {max_gap}")
    return longest_gap_index - 1

assert get_longest_gap([1,2,4,6,20,24]) == 3 # "6"
# Out:
# The longest gap is between 6 and 20
# With a gap of 14

# %%
get_longest_gap(newminutes)
# Out:
# The longest gap is between 346 and 352
# With a gap of 6
# 248

# %%
newbuckets = defaultdict(list)
for row in newquotes:
    newbuckets[row['time']].append(row)
print(f"Number of time buckets: {len(newbuckets.keys())}")
print(f"Number of minutes in a day: {60 * 24}")
print(f"diff: {len(newbuckets.keys()) - (60*24)}")
# Out:
# Number of time buckets: 999
# Number of minutes in a day: 1440
# diff: -441

# %%
print(newbuckets["05:46"])
# Out:
# [OrderedDict([('time', '05:46'), ('time_string', '5.46am'), ('quote', "He wrote a legal-sounding phrase to the effect that the sentence had been carried out at 5.46am, adding, 'without a snag'."), ('book', 'A Whispered Name'), ('author', 'William Brodrick')]), OrderedDict([('time', '05:46'), ('time_string', 'fourteen minutes to six'), ('quote', '...those of the carriage clock on the bookshelf to fourteen minutes to six. In other words, it was exactly eight; and Mrs. Hignett acknowledged the fact...'), ('book', 'Three Men and a Maid'), ('author', 'P.G. Wodehouse')])]

# %%
print(newbuckets["05:52"])
# Out:
# [OrderedDict([('time', '05:52'), ('time_string', '5.52am'), ('quote', 'At 5.52am paramedics from the St. Petersburg Fire Department and SunStar Medic One ambulance service responded to a medical emergency call...'), ('book', 'Silent Witness'), ('author', 'Mark Fuhrman')])]
